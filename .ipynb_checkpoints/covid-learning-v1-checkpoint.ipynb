# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# read data
df = pd.read_csv("test.csv")
df.drop(columns=df.columns[0], 
        axis=1, 
        inplace=True)

# %%
ls data
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is FEB5-37D9
#
#  Directory of C:\Users\hlu\Desktop\github\covid-learning\data
#
# 09/08/2021  11:08 AM    <DIR>          .
# 09/08/2021  11:08 AM    <DIR>          ..
# 07/27/2021  05:36 PM            13,560 districts_info.csv
# 09/08/2021  11:08 AM    <DIR>          engagement_data
# 07/27/2021  05:37 PM            44,683 products_info.csv
# 07/27/2021  05:36 PM             6,117 README.md
#                3 File(s)         64,360 bytes
#                3 Dir(s)  242,307,751,936 bytes free

# %%
districts = pd.read_csv('data/districts_info.csv')

districts.head()
# Out:
#    district_id     state  locale pct_black/hispanic pct_free/reduced  \
# 0         8815  Illinois  Suburb           [0, 0.2[         [0, 0.2[
# 1         2685       NaN     NaN                NaN              NaN
# 2         4921      Utah  Suburb           [0, 0.2[       [0.2, 0.4[
# 3         3188       NaN     NaN                NaN              NaN
# 4         2238       NaN     NaN                NaN              NaN
#
#   county_connections_ratio    pp_total_raw
# 0                [0.18, 1[  [14000, 16000[
# 1                      NaN             NaN
# 2                [0.18, 1[    [6000, 8000[
# 3                      NaN             NaN
# 4                      NaN             NaN

# %%
products = pd.read_csv('data/products_info.csv')
products.head()
# Out:
#    LP ID                           URL  Product Name  Provider/Company Name  \
# 0  13117    https://www.splashmath.com   SplashLearn          StudyPad Inc.
# 1  66933          https://abcmouse.com  ABCmouse.com  Age of Learning, Inc
# 2  50479         https://www.abcya.com        ABCya!         ABCya.com, LLC
# 3  92993         http://www.aleks.com/         ALEKS    McGraw-Hill PreK-12
# 4  73104  https://www.achieve3000.com/   Achieve3000            Achieve3000
#
#             Sector(s)                         Primary Essential Function
# 0             PreK-12                    LC - Digital Learning Platforms
# 1             PreK-12                    LC - Digital Learning Platforms
# 2             PreK-12  LC - Sites, Resources & Reference - Games & Si...
# 3  PreK-12; Higher Ed                    LC - Digital Learning Platforms
# 4             PreK-12                    LC - Digital Learning Platforms

# %%
districts.groupby(by='state')['state'].count().sort_values()
# Out:
# state
# Arizona                  1
# North Dakota             1
# Florida                  1
# Minnesota                1
# Texas                    2
# Tennessee                2
# New Jersey               2
# Michigan                 2
# New Hampshire            2
# District Of Columbia     3
# Wisconsin                3
# North Carolina           4
# Virginia                 4
# Missouri                 6
# Washington               6
# Indiana                  7
# New York                 8
# Ohio                    11
# California              12
# Illinois                18
# Massachusetts           21
# Utah                    29
# Connecticut             30
# Name: state, dtype: int64

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 372 entries, 0 to 371
# Data columns (total 6 columns):
# LP ID                         372 non-null int64
# URL                           372 non-null object
# Product Name                  372 non-null object
# Provider/Company Name         371 non-null object
# Sector(s)                     352 non-null object
# Primary Essential Function    352 non-null object
# dtypes: int64(1), object(5)
# memory usage: 17.5+ KB

# %%
products['Sector(s)'].value_counts()
# Out:
# PreK-12                          170
# PreK-12; Higher Ed; Corporate    115
# PreK-12; Higher Ed                65
# Corporate                          1
# Higher Ed; Corporate               1
# Name: Sector(s), dtype: int64

# %%
products['Primary Essential Function'].value_counts()
# Out:
# LC - Digital Learning Platforms                                              74
# LC - Sites, Resources & Reference                                            47
# LC - Content Creation & Curation                                             36
# LC - Study Tools                                                             25
# LC - Courseware & Textbooks                                                  18
# LC - Sites, Resources & Reference - Games & Simulations                      18
# LC/CM/SDO - Other                                                            16
# LC - Sites, Resources & Reference - Digital Collection & Repository          15
# CM - Classroom Engagement & Instruction - Classroom Management               11
# LC - Sites, Resources & Reference - Streaming Services                        9
# CM - Virtual Classroom - Video Conferencing & Screen Sharing                  7
# SDO - Data, Analytics & Reporting - Site Hosting & Data Warehousing           6
# LC - Study Tools - Q&A                                                        6
# LC - Online Course Providers & Technical Skills Development                   5
# CM - Classroom Engagement & Instruction - Communication & Messaging           5
# SDO - Learning Management Systems (LMS)                                       5
# CM - Classroom Engagement & Instruction - Assessment & Classroom Response     4
# SDO - Human Resources                                                         4
# LC - Sites, Resources & Reference - Thesaurus & Dictionary                    4
# LC - Sites, Resources & Reference - Encyclopedia                              4
# LC - Sites, Resources & References - Learning Materials & Supplies            4
# LC - Career Planning & Job Search                                             3
# CM - Teacher Resources - Professional Learning                                3
# CM - Teacher Resources - Lesson Planning                                      3
# LC - Study Tools - Test Prep & Study Skills                                   3
# SDO - Data, Analytics & Reporting                                             3
# SDO - School Management Software - Mobile Device Management                   2
# SDO - School Management Software - SSO                                        2
# SDO - Data, Analytics & Reporting - Student Information Systems (SIS)         2
# SDO - Large-Scale & Standardized Testing                                      2
# SDO - Other                                                                   2
# SDO - Admissions, Enrollment & Rostering                                      1
# LC - Study Tools - Tutoring                                                   1
# CM - Teacher Resources - Grading & Attendance                                 1
# SDO - Environmental, Health & Safety (EHS) Compliance                         1
# Name: Primary Essential Function, dtype: int64

# %%
# How does student engagement with different types of education technology change over the course of the pandemic?
file  = 'data/engagement_data/8815.csv'
engagement = pd.read_csv(file)
engagement['time'] = pd.to_datetime(engagement['time'])
from datetime import date
engagement['weekday'] = engagement['time'].apply(date.weekday)
engagement.set_index('time', inplace=True)
engagement.head()
# Out:
#             lp_id  pct_access  engagement_index  weekday
# time
# 2020-01-27  32213      100.00           3000.00        0
# 2020-02-25  90153       33.33           2666.67        1
# 2020-02-25  99916        0.00               NaN        1
# 2020-02-25  28504        0.00               NaN        1
# 2020-02-25  95731       33.33            333.33        1

# %%
engagement.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 134926 entries, 2020-01-27 to 2020-12-31
# Data columns (total 4 columns):
# lp_id               134926 non-null int64
# pct_access          134926 non-null float64
# engagement_index    103720 non-null float64
# weekday             134926 non-null int64
# dtypes: float64(2), int64(2)
# memory usage: 10.1 MB

# %%
# sort products based on count of days of observations 
lp_count_days = engagement.groupby(by='lp_id')['lp_id'].count().sort_values(ascending=False)

lp_count_days.head()
# Out:
# lp_id
# 95731    311
# 32213    311
# 90153    310
# 99916    310
# 28504    310
# Name: lp_id, dtype: int64

# %%
# hypothsis: products with less observations tend to have low engagment_index
# finding: most products have low engagement index
lp_engagement_mean = engagement.groupby(by='lp_id')['engagement_index'].mean()

temp = pd.DataFrame()
temp['count'] = lp_count_days
temp['engagement'] = lp_engagement_mean
temp.head()
temp.plot.scatter(x='count', y='engagement')

# %%
# products with high engagement and their information
temp['engagement'].sort_values(ascending=False).head()
# Out:
# lp_id
# 95731    31701.653891
# 26488    14960.921036
# 32213    13400.379164
# 98845     9843.200000
# 61292     6785.880253
# Name: engagement, dtype: float64

# %%
lp_id = 32213
engagement[engagement['lp_id'] == lp_id]['engagement_index'].plot()
plt.show()

from datetime import date
engagement[engagement['lp_id'] == lp_id][['time','weekday','engagement_index']]

# findings: (i) significant drop on online learning tool usage during weekends
# Out:
#              time  weekday  engagement_index
# 0      2020-01-27        0           3000.00
# 6      2020-02-26        2           1750.00
# 61     2020-02-27        3          12947.27
# 461    2020-02-28        4            892.04
# 670    2020-02-29        5            643.35
# 810    2020-03-01        6           1121.12
# 1303   2020-03-02        0          20096.50
# 1800   2020-03-03        1          21718.99
# 2019   2020-03-04        2          20748.48
# 2913   2020-03-05        3          18106.88
# 3090   2020-03-06        4          18928.78
# 3551   2020-03-07        5            486.24
# 3750   2020-03-08        6            802.73
# 4209   2020-03-09        0          19284.95
# 4727   2020-03-10        1          18669.54
# 4958   2020-03-11        2          16338.11
# 5425   2020-03-12        3          18323.53
# 5817   2020-03-13        4          18272.28
# 6433   2020-03-14        5           1778.48
# 6636   2020-03-15        6           1134.13
# 6754   2020-03-16        0           4239.98
# 7387   2020-03-17        1          13667.56
# 7456   2020-03-18        2          61550.71
# 8393   2020-03-19        3          51720.22
# 8539   2020-03-20        4          46479.52
# 9231   2020-03-21        5           4671.87
# 9328   2020-03-22        6           3107.41
# 9920   2020-03-23        0          48357.07
# 10353  2020-03-24        1          43795.13
# 10843  2020-03-25        2          47280.79
# ...           ...      ...               ...
# 122198 2020-12-02        2          33512.94
# 122972 2020-12-03        3          29750.78
# 123459 2020-12-04        4          33110.11
# 123831 2020-12-05        5           1536.07
# 124234 2020-12-06        6           2083.88
# 124825 2020-12-07        0          29493.87
# 125557 2020-12-08        1          32305.90
# 126388 2020-12-09        2          34646.31
# 126802 2020-12-10        3          33400.28
# 127367 2020-12-11        4          32506.04
# 128041 2020-12-12        5           1885.61
# 128266 2020-12-13        6           2809.35
# 128625 2020-12-14        0          29697.03
# 129647 2020-12-15        1          29114.20
# 130283 2020-12-16        2          34819.73
# 130879 2020-12-17        3          37724.17
# 131817 2020-12-18        4          34266.69
# 132189 2020-12-19        5           1229.43
# 132419 2020-12-20        6            524.75
# 132695 2020-12-21        0            671.73
# 133004 2020-12-22        1            456.27
# 133247 2020-12-23        2            451.10
# 133361 2020-12-24        3            249.27
# 133562 2020-12-25        4             61.93
# 133592 2020-12-26        5            128.34
# 133817 2020-12-27        6            124.37
# 133972 2020-12-28        0            209.42
# 134289 2020-12-29        1            221.67
# 134579 2020-12-30        2            226.15
# 134817 2020-12-31        3            242.54
#
# [311 rows x 3 columns]

# %%
lp_id = 63632
engagement[engagement['lp_id'] == lp_id]['engagement_index'].rolling(7, min_periods=1).mean().plot()

# %%
subset = engagement.loc['2020-03-15': '2020-04-15']
subset[subset['lp_id'] == lp_id]
# Out:
#             lp_id  pct_access  engagement_index  weekday
# time
# 2020-03-15  32213        9.35           1134.13        6
# 2020-03-16  32213       21.37           4239.98        0
# 2020-03-17  32213       41.39          13667.56        1
# 2020-03-18  32213       76.17          61550.71        2
# 2020-03-19  32213       76.50          51720.22        3
# 2020-03-20  32213       74.00          46479.52        4
# 2020-03-21  32213       25.02           4671.87        5
# 2020-03-22  32213       17.08           3107.41        6
# 2020-03-23  32213       73.38          48357.07        0
# 2020-03-24  32213       72.70          43795.13        1
# 2020-03-25  32213       76.76          47280.79        2
# 2020-03-26  32213       76.04          42086.77        3
# 2020-03-27  32213       31.21           5157.75        4
# 2020-03-28  32213       10.88           1064.50        5
# 2020-03-29  32213        7.52            589.61        6
# 2020-03-30  32213       11.47           1201.67        0
# 2020-03-31  32213        9.76            814.50        1
# 2020-04-01  32213        8.56            789.61        2
# 2020-04-02  32213        7.59            638.96        3
# 2020-04-03  32213        7.11            566.48        4
# 2020-04-04  32213        5.78            446.64        5
# 2020-04-05  32213        8.66            801.79        6
# 2020-04-06  32213       75.23          26504.09        0
# 2020-04-07  32213       75.33          25369.79        1
# 2020-04-08  32213       74.74          23256.18        2
# 2020-04-09  32213       75.97          23737.59        3
# 2020-04-10  32213       75.67          24695.63        4
# 2020-04-11  32213       19.39           6934.22        5
# 2020-04-12  32213       11.62           3641.06        6
# 2020-04-13  32213       76.76          26370.77        0
# 2020-04-14  32213       78.11          26065.75        1
# 2020-04-15  32213       77.88          24511.78        2
